# %%
from pathlib import Path

# %% [markdown]
# SDFCU Importer

# %%
from importer import sdfcu_parse

sdfcu_parse(Path("/home/hans/finances/imports/sdfcu/checking/BASIC CHECKING Transactions 20250822_20260826.csv"))
# Out:
# [ParsedRecord(record_id='sdfcu:20260826:61558', source='sdfcu', source_file=PosixPath('/home/hans/finances/imports/sdfcu/checking/BASIC CHECKING Transactions 20250822_20260826.csv'), source_row=2, source_id='20260826:61558', date=datetime.date(2026, 8, 26), time=None, completed_at=None, description='Transfer From CLARKSONBRIAN', amount=Decimal('1000.00'), currency='USD', balance=Decimal('1159.90'), balance_currency='USD', counterparty=None, category='Transfers', payment_method=None, reference=None, note=None, tags=[], payment_type=None, installment_number=None, payment_amount=None, source_amount=None, source_currency=None, target_amount=None, target_currency=None, exchange_rate=None, conversion_date=None, fee_amount=None, fee_currency=None, raw_data={'Account ID': '316789-S0001', 'Transaction ID': '20260826:61558', 'Date': '08/26/26', 'Description': ' Transfer From CLARKSONBRIAN ', 'Check Number': '', 'Category': 'Transfers', 'Tags': '', 'Amount': '$1,000.00', 'Balance': '$1,159.90'}
# ...

# %% [markdown]
# Sumitomo Banking Importer

# %%
from importer import sumitomo_parse

sumitomo_parse(Path("/home/hans/finances/imports/sumitomo/olive_ecru/bank/meisai 2025-4-5 2026-8-26.csv"))
# Out:
# [ParsedRecord(record_id='sumitomo_bank:6fe00e807387f75ff592a9b50c344e4f2d11eda5a978605389fa83bb9d8add58', source='sumitomo_bank', source_file=PosixPath('/home/hans/finances/imports/sumitomo/olive_ecru/bank/meisai 2025-4-5 2026-8-26.csv'), source_row=2, source_id=None, date=datetime.date(2026, 8, 26), time=None, completed_at=None, description='ﾐﾂｲｽﾐﾄﾓｶ-ﾄﾞ (ｶ', amount=Decimal('-99709'), currency='JPY', balance=Decimal('1756901'), balance_currency='JPY', counterparty=None, category=None, payment_method=None, reference=None, note=None, tags=[], payment_type=None, installment_number=None, payment_amount=None, source_amount=None, source_currency=None, target_amount=None, target_currency=None, exchange_rate=None, conversion_date=None, fee_amount=None, fee_currency=None, raw_data={'年月日': '2026/8/26', 'お引出し': '99709', 'お預入れ': '', 'お取り扱い内容': 'ﾐﾂｲｽﾐﾄﾓｶ-ﾄﾞ (ｶ', '残高': '1756901', 'メモ': '', 'ラベル': ''}),
# ...

# %% [markdown]
# Sumitomo Credit Card Importer

# %%
from importer import sumitomo_credit_card_parse

sumitomo_credit_card_parse(Path("/home/hans/finances/imports/sumitomo/olive_ecru/credit_card/202506.csv"))
# Out:
# [ParsedRecord(record_id='sumitomo_credit_card:9896ebb3d1cc9c7697e67c8ac56ae3964bcfa683758e914a4313e87f00b7958f', source='sumitomo_credit_card', source_file=PosixPath('/home/hans/finances/imports/sumitomo/olive_ecru/credit_card/202506.csv'), source_row=2, source_id=None, date=datetime.date(2025, 5, 2), time=None, completed_at=None, description='セイユウ', amount=Decimal('537'), currency='JPY', balance=None, balance_currency='JPY', counterparty=None, category=None, payment_method=None, reference=None, note=None, tags=[], payment_type='１', installment_number=1, payment_amount=Decimal('537'), source_amount=None, source_currency=None, target_amount=None, target_currency=None, exchange_rate=None, conversion_date=None, fee_amount=None, fee_currency=None, raw_data={'column_1': '2025/05/02', 'column_2': 'セイユウ', 'column_3': '537', 'column_4': '１', 'column_5': '１', 'column_6': '537', 'column_7': ''}),
# ...

# %% [markdown]
# PayPay Importer

# %%
from importer import paypay_parse

paypay_parse(Path("/home/hans/finances/imports/paypay/Transactions_20240826-20250826.csv"))
# Out:
# [ParsedRecord(record_id='paypay:04778060338658107393', source='paypay', source_file=PosixPath('/home/hans/finances/imports/paypay/Transactions_20240826-20250826.csv'), source_row=2, source_id='04778060338658107393', date=datetime.date(2025, 8, 17), time=datetime.time(7, 57, 12), completed_at=None, description='支払い', amount=Decimal('-349'), currency='JPY', balance=None, balance_currency='JPY', counterparty='Google', category=None, payment_method='PayPay残高', reference=None, note=None, tags=[], payment_type=None, installment_number=None, payment_amount=None, source_amount=None, source_currency=None, target_amount=None, target_currency=None, exchange_rate=None, conversion_date=None, fee_amount=None, fee_currency=None, raw_data={'取引日': '2025/08/17 07:57:12', '出金金額（円）': '349', '入金金額（円）': '-', '海外出金金額': '-', '通貨': '-', '変換レート（円）': '-', '利用国': '-', '取引内容': '支払い', '取引先': 'Google', '取引方法': 'PayPay残高', '支払い区分': '-', '利用者': '-', '取引番号': '04778060338658107393'}),
# ...

# %% [markdown]
# Wise Importer

# %%
from importer import wise_parse

wise_parse(Path("/home/hans/finances/imports/wise/transaction-history 2025-9-3 2026-5-18.csv"))
# Out:
# [ParsedRecord(record_id='wise:TRANSFER-2138757363', source='wise', source_file=PosixPath('/home/hans/finances/imports/wise/transaction-history 2025-9-3 2026-5-18.csv'), source_row=2, source_id='TRANSFER-2138757363', date=datetime.date(2026, 5, 17), time=datetime.time(22, 20, 19), completed_at=datetime.datetime(2026, 5, 18, 13, 33, 50), description='General', amount=Decimal('-436.79'), currency='USD', balance=None, balance_currency=None, counterparty='Toren Clarkson', category='General', payment_method=None, reference=None, note=None, tags=[], payment_type=None, installment_number=None, payment_amount=None, source_amount=Decimal('436.79'), source_currency='USD', target_amount=Decimal('436.79'), target_currency='USD', exchange_rate=Decimal('1.0'), conversion_date=None, fee_amount=Decimal('1.13'), fee_currency='USD', raw_data={'ID': 'TRANSFER-2138757363', 'Status': 'COMPLETED', 'Direction': 'OUT', 'Created on': '2026-05-17 22:20:19', 'Finished on': '2026-05-18 13:33:50', 'Source fee amo
# ...
